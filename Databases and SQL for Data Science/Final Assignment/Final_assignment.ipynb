# %%
import mysql.connector
import pandas as pd

connection = mysql.connector.connect(host='localhost', database='CHICAGO', user='root', password='your_password_here')
df = pd.read_sql('SELECT COUNT(*) FROM CRIME', connection)
df.head()
# Out:
#    COUNT(*)
# 0       533

# %%
df = pd.read_sql('SELECT * FROM CRIME LIMIT 10', connection)
df.head()
# Out:
#         ID CASE_NUMBER                    DATE                BLOCK  IUCR  \
# 0    21149    HW519443  11/03/2013 07:27:00 PM  044XX S RICHMOND ST   110
# 1    23469    JA359626  07/23/2017 09:25:00 AM      015XX E 82ND ST   110
# 2  1326195     G021609  01/11/2001 02:30:41 AM  087XX S ESCANABA AV  9901
# 3  1340847     G040244  01/19/2001 06:39:03 PM     063XX N NAGLE AV   820
# 4  1353618     G056330  01/27/2001 04:20:00 PM    078XX S SAWYER AV   460
#
#         PRIMARY_TYPE          DESCRIPTION     LOCATION_DESCRIPTION ARREST  \
# 0           HOMICIDE  FIRST DEGREE MURDER                    HOUSE   TRUE
# 1           HOMICIDE  FIRST DEGREE MURDER                   STREET  FALSE
# 2  DOMESTIC VIOLENCE    DOMESTIC VIOLENCE                APARTMENT   TRUE
# 3              THEFT       $500 AND UNDER       GROCERY FOOD STORE   TRUE
# 4            BATTERY               SIMPLE  RESIDENCE PORCH/HALLWAY   TRUE
#
#   DOMESTIC  ... WARD  COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE  \
# ...

# %%
df = pd.read_sql('SELECT DISTINCT(PRIMARY_TYPE) FROM CRIME where LOCATION_DESCRIPTION = "GAS STATION"', connection)
df.head()
# Out:
#         PRIMARY_TYPE
# 0            ROBBERY
# 1              THEFT
# 2  CRIMINAL TRESPASS
# 3          NARCOTICS

# %%
df = pd.read_sql('SELECT * FROM CENSUS', connection)
df.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                      1         Rogers Park                         7.7
# 1                      2          West Ridge                         7.8
# 2                      3              Uptown                         3.8
# 3                      4      Lincoln Square                         3.4
# 4                      5        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_OVER_16_UNEMPLOYED  \
# 0                              23.6                              8.7
# 1                              17.2                              8.8
# 2                              24.0                              8.9
# 3                              10.9                              8.2
# 4                               7.5                              5.2
#
#    PERCENT_AGED_OVER_25_WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 0                                              18.2
# ...

# %%
df = pd.read_sql('SELECT * FROM CENSUS WHERE COMMUNITY_AREA_NAME LIKE "B%"', connection)
df.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                     19      Belmont Cragin                        10.8
# 1                     47            Burnside                         6.8
# 2                     58       Brighton Park                        14.4
# 3                     60          Bridgeport                         4.5
# 4                     72             Beverly                         0.9
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_OVER_16_UNEMPLOYED  \
# 0                              18.7                             14.6
# 1                              33.0                             18.6
# 2                              23.6                             13.9
# 3                              18.9                             13.7
# 4                               5.1                              8.0
#
#    PERCENT_AGED_OVER_25_WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 0                                              37.3
# ...

# %%
df = pd.read_sql('SELECT * FROM PUBLIC_SCHOOLS', connection)
df.head()
# Out:
#    SCHOOL_ID                                     NAME_OF_SCHOOL  \
# 0     400018  Austin Business and Entrepreneurship Academy H...
# 1     609674      Chicago Vocational Career Academy High School
# 2     609676    Paul Laurence Dunbar Career Academy High School
# 3     609678      William Jones College Preparatory High School
# 4     609679   Charles Allen Prosser Career Academy High School
#
#   ELEMENTARY_MIDDLE_OR_HIGH_SCHOOL    STREET_ADDRESS     CITY STATE ZIP_CODE  \
# 0                               HS   231 N Pine Ave   Chicago    IL    60644
# 1                               HS   2100 E 87th St   Chicago    IL    60617
# 2                               HS   3000 S King Dr   Chicago    IL    60616
# 3                               HS   606 S State St   Chicago    IL    60605
# 4                               HS  2148 N Long Ave   Chicago    IL    60639
#
#      PHONE_NUMBER                                               LINK  \
# 0  (773) 534-6316
# ...

# %%
df = pd.read_sql('SELECT NAME_OF_SCHOOL FROM PUBLIC_SCHOOLS WHERE (COMMUNITY_AREA_NUMBER BETWEEN 10 AND 15) AND HEALTHY_SCHOOL_CERTIFIED = "Yes"', connection)
df.head()
# Out:
#                     NAME_OF_SCHOOL
# 0  Rufus M Hitch Elementary School

# %%
df = pd.read_sql('SELECT AVG(SAFETY_SCORE) FROM PUBLIC_SCHOOLS', connection)
df.head()
# Out:
#    AVG(SAFETY_SCORE)
# 0            44.7735

# %%
df = pd.read_sql('SELECT COMMUNITY_AREA_NAME, AVG(COLLEGE_ENROLLMENT) FROM PUBLIC_SCHOOLS GROUP BY COMMUNITY_AREA_NAME ORDER BY AVG(COLLEGE_ENROLLMENT) DESC LIMIT 5', connection)
df.head()
# Out:
#   COMMUNITY_AREA_NAME  AVG(COLLEGE_ENROLLMENT)
# 0      ARCHER HEIGHTS                2411.5000
# 1           MONTCLARE                1317.0000
# 2         WEST ELSDON                1233.3333
# 3       BRIGHTON PARK                1205.8750
# 4      BELMONT CRAGIN                1198.8333

# %%
df = pd.read_sql('SELECT SAFETY_SCORE, COMMUNITY_AREA_NAME FROM PUBLIC_SCHOOLS WHERE SAFETY_SCORE = (SELECT MIN(SAFETY_SCORE) FROM PUBLIC_SCHOOLS)', connection)
df.head()
# Out:
#    SAFETY_SCORE COMMUNITY_AREA_NAME
# 0             0            ROSELAND
# 1             0             DOUGLAS
# 2             0      WEST ENGLEWOOD
# 3             0             KENWOOD
# 4             0        LINCOLN PARK

# %%
df = pd.read_sql('SELECT CENSUS.PER_CAPITA_INCOME, PUBLIC_SCHOOLS.COMMUNITY_AREA_NAME FROM PUBLIC_SCHOOLS, CENSUS WHERE PUBLIC_SCHOOLS.COMMUNITY_AREA_NUMBER = CENSUS.COMMUNITY_AREA_NUMBER AND SAFETY_SCORE = 1', connection)
df.head()
# Out:
#    PER_CAPITA_INCOME COMMUNITY_AREA_NAME
# 0              13785     WASHINGTON PARK

# %%
connection.close()
